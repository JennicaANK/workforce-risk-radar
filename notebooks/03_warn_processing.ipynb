# %% [markdown]
# # 03 - WARN PDF Extraction (Save interim CSV fragments)
#
# Goal:
# - Extract table-like content from CA WARN PDFs into multiple CSV fragments per PDF.
# - keep only rows that contain a real WARN event string
# - extract employee counts safely
# - remove address-derived fake values
# - export trustworthy row-level and monthly WARN outputs
#
# Input: data/raw/warn_pdf/*.pdf
# Output (interim): data/interim/warn_tables/*.csv
#
# Each PDF page is extracted separately; Tabula often returns one CSV per detected table region, so a single PDF becomes many fragments.

# %%
# pip install tabula-py

# %% [markdown]
# 01: Load All Extracted Tables
#
# Goal: Load every extracted CSV fragment so we can filter out the junk tables and clean real rows.

# %%
import pandas as pd
import tabula
import glob
import os
import numpy as np
import re

# %%
pdf_files = sorted(glob.glob("../data/raw/warn_pdf/*.pdf"))

pdf_files
# Out:
# ['../data/raw/warn_pdf/warn7-1-20to6-3-21.pdf',
#  '../data/raw/warn_pdf/warn7-1-21to6-30-22.pdf',
#  '../data/raw/warn_pdf/warn7-1-22to06-30-23.pdf',
#  '../data/raw/warn_pdf/warn7-1-23-to6-30-24.pdf',
#  '../data/raw/warn_pdf/warn7-1-24to6-30-25.pdf']

# %%
os.makedirs("../data/interim/warn_tables", exist_ok=True)

for pdf in pdf_files:
    base = os.path.splitext(os.path.basename(pdf))[0]
    print(f"Extracting: {base}")
    
    dfs = tabula.read_pdf(
        pdf,
        pages="all",
        multiple_tables=True,
        stream=True,
        guess=False
    )
    print(f"  tables found: {len(dfs)}")
    
    # Save each extracted table
    for i, df in enumerate(dfs):
        out_path = f"../data/interim/warn_tables/{base}_table{i}.csv"
        df.to_csv(out_path, index=False)
# Out:
# Extracting: warn7-1-20to6-3-21
#   tables found: 117
# Extracting: warn7-1-21to6-30-22
#   tables found: 31
# Extracting: warn7-1-22to06-30-23
#   tables found: 44
# Extracting: warn7-1-23-to6-30-24
#   tables found: 66
# Extracting: warn7-1-24to6-30-25
#   tables found: 55

# %% [markdown]
# 02: Load extracted tables and inspect
#
# Goal: Load all extracted CSV fragments and see what kinds of columns/headers we got.
# This step helps us identify:
#
# junk header tables (like “WARN Report” summary pages)
#
# real data tables (notice/effective/received/company/county/employees/type)

# %%
table_files = sorted(glob.glob("../data/interim/warn_tables/*.csv"))
print("Total extracted CSV fragments:", len(table_files))
table_files[:5]
# Out:
# Total extracted CSV fragments: 313
# ['../data/interim/warn_tables/warn7-1-20to6-3-21_table0.csv',
#  '../data/interim/warn_tables/warn7-1-20to6-3-21_table1.csv',
#  '../data/interim/warn_tables/warn7-1-20to6-3-21_table10.csv',
#  '../data/interim/warn_tables/warn7-1-20to6-3-21_table100.csv',
#  '../data/interim/warn_tables/warn7-1-20to6-3-21_table101.csv']

# %%
def load_warn_fragment(file_path: str) -> pd.DataFrame:
    """
    Load one extracted WARN CSV fragment safely.
    We use header=None so pandas does not accidentally treat a data row as the header.
    """
    df = pd.read_csv(file_path, header=None)
    df["source_file"] = os.path.basename(file_path)
    return df

# %%
sample_df = load_warn_fragment(table_files[0])
sample_df.head(10)
# Out:
#             0           1           2                       3  \
# 0  Unnamed: 0  Unnamed: 1  Unnamed: 2              Unnamed: 3
# 1         NaN         NaN         NaN                     NaN
# 2         NaN         NaN         NaN                     NaN
# 3      Notice   Effective    Received                     NaN
# 4        Date        Date        Date                 Company
# 5  06/09/2020  06/07/2020  07/01/2020   Bay Club Santa Monica
# 6  06/19/2020  08/21/2020  07/01/2020       Weber Metals, Inc
# 7  06/09/2020  06/07/2020  07/01/2020  Bay Club Rolling Hills
# 8  06/09/2020  06/07/2020  07/01/2020  Bay Club Redondo Beach
# 9  06/09/2020  06/07/2020  07/01/2020    Bay Club Ross Valley
#
#                               4                   5  \
# 0                   WARN Report          Unnamed: 4
# 1  Summary by State Fiscal Year                 NaN
# 2  July 1, 2020 - June 30, 2021                 NaN
# 3                           NaN                 NaN
# 4                          City              County
# 5                  Santa Monica  Los Angeles County
# 6                     Paramount  Los Angeles County
# 7         Rolling Hills Estates  Los Angeles County
# 8                 Redondo Beach  Los Angeles County
# 9                     Kentfield        Marin County
#
#                                6                    source_file
# 0                     Unnamed: 5  warn7-1-20to6-3-21_table0.csv
# 1                            NaN  warn7-1-20to6-3-21_table0.csv
# 2                            NaN  warn7-1-20to6-3-21_table0.csv
# 3                         No. Of  warn7-1-20to6-3-21_table0.csv
# 4  Employees Layoff/Closure Type  warn7-1-20to6-3-21_table0.csv
# 5            82 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 6           169 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 7            64 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 8           102 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 9            51 Layoff Permanent  warn7-1-20to6-3-21_table0.csv

# %% [markdown]
# 03: Standardize columns (fix “Unnamed: 0” headers)
#
# Problem: Some fragments have real column names, others have Unnamed: 0, etc.
# Plan: Rename columns by position into a consistent schema:
#
# Target columns:
# - notice_date
# - effective_date
# - received_date
# - company
# - city
# - county
# - employees
# - layoff_closure_type
#
# We will keep extra columns only if needed later.

# %%
# def standardize_warn_fragment(df: pd.DataFrame) -> pd.DataFrame:
#     """
#     Standardize one extracted WARN table fragment.

#     Handles two main layouts:

#     Layout A (older):
#     notice_date | effective_date | received_date | company | city | county | employees_type

#     Layout B (newer):
#     notice_date | effective_date | received_date | company | county | employees_type | address
#     """
#     df = df.copy()

#     # Keep first 7 columns + source_file
#     keep_cols = list(df.columns[:7]) + ["source_file"]
#     df = df[keep_cols]

#     # Temporary names
#     df.columns = [
#         "col0", "col1", "col2", "col3", "col4", "col5", "col6", "source_file"
#     ]

#     # Convert to strings
#     for c in ["col0", "col4", "col5", "col6"]:
#         df[c] = df[c].astype(str).str.strip()

#     # Only inspect rows that LOOK like real data rows
#     date_like = df["col0"].str.match(r"^\d{1,2}/\d{1,2}/\d{4}$", na=False)
#     sample = df.loc[date_like, ["col4", "col5", "col6"]].head(20).copy()

#     # Stronger layout detection using actual WARN keywords
#     col4_has_county = sample["col4"].str.contains("County", case=False, na=False).mean()
#     col5_has_county = sample["col5"].str.contains("County", case=False, na=False).mean()

#     col5_has_warn_type = sample["col5"].str.contains(
#         r"(Layoff|Closure|Relocation|Temporary|Permanent|Unknown|Not known)",
#         case=False,
#         na=False
#     ).mean()

#     col6_is_address = sample["col6"].str.contains(r"CA|Way|Blvd|Street|Rd", case=False, na=False).mean()

#     # Layout A: city | county | employees_type
#     if col5_has_county > 0.3 and col6_has_warn_type > 0.3:
#         df = df.rename(columns={
#             "col0": "notice_date",
#             "col1": "effective_date",
#             "col2": "received_date",
#             "col3": "company",
#             "col4": "city",
#             "col5": "county",
#             "col6": "employees_type"
#         })
#         df["address"] = pd.NA

#     # Layout B: county | employees_type | address
#     if col4_has_county > 0.3 and col5_starts_num > 0.3 and col6_is_address > 0.3:
#     # Standardize as Layout B
#         df.rename(columns={
#             "col0": "notice_date", "col1": "received_date", "col2": "effective_date",
#             "col3": "company", "col4": "county", "col5": "employees_type", "col6": "address"
#         }, inplace=True)
#         df["city"] = pd.NA

#     # Fallback: choose whichever column looks more like WARN type
#     elif col6_has_warn_type >= col5_has_warn_type:
#         df = df.rename(columns={
#             "col0": "notice_date",
#             "col1": "effective_date",
#             "col2": "received_date",
#             "col3": "company",
#             "col4": "city",
#             "col5": "county",
#             "col6": "employees_type"
#         })
#         df["address"] = pd.NA
#     else:
#         df = df.rename(columns={
#             "col0": "notice_date",
#             "col1": "effective_date",
#             "col2": "received_date",
#             "col3": "company",
#             "col4": "county",
#             "col5": "employees_type",
#             "col6": "address"
#         })
#         df["city"] = pd.NA

#     return df

# %%
def standardize_warn_fragment(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    num_cols = len(df.columns)
    temp_names = [f"col{i}" for i in range(min(num_cols, 8))]
    
    keep_cols = list(df.columns[:len(temp_names)])
    if "source_file" in df.columns:
        df = df[keep_cols + ["source_file"]]
        df.columns = temp_names + ["source_file"]
    else:
        df = df[keep_cols]
        df.columns = temp_names

    for c in [c for c in df.columns if c not in ["source_file"]]:
        df[c] = df[c].astype(str).str.strip()

    sample = df.dropna(subset=["col0"]).head(20)
    col4_has_county = sample["col4"].str.contains("County", case=False, na=False).mean()
    col5_has_county = sample["col5"].str.contains("County", case=False, na=False).mean()
    
    # Improved check: Employees columns are usually short (1-4 digits) 
    # while addresses are long and contain keywords like "Way" or "St"
    col5_is_address = sample["col5"].str.contains(r"Way|Blvd|Street|Rd|Ave", case=False, na=False).mean()
    col5_starts_num = sample["col5"].str.match(r"^\d", na=False).mean()

    # LAYOUT A: Older PDFs (Notice, Effective, Received, Company, City, County, Employees)
    if col5_has_county > 0.3:
        df = df.rename(columns={
            "col0": "notice_date", "col1": "effective_date", "col2": "received_date",
            "col3": "company", "col4": "city", "col5": "county", "col6": "employees_type"
        })
        df["address"] = pd.NA

    # LAYOUT B: Newer PDFs (Notice, Received, Effective, Company, County, Employees, Type, Address)
    elif col4_has_county > 0.3:
        df = df.rename(columns={
            "col0": "notice_date", 
            "col1": "received_date", # Swapped in 2024 
            "col2": "effective_date", # Swapped in 2024 
            "col3": "company", "col4": "county", "col5": "employees_type",
            "col6": "layoff_closure_type_raw", "col7": "address"
        })
        df["city"] = pd.NA
        if "col7" in df.columns:
            df["employees_type"] = df["employees_type"] + " " + df["layoff_closure_type_raw"].fillna("")
    
    else:
        # Fallback to standard layout 
        df = df.rename(columns={
            "col0": "notice_date", "col1": "effective_date", "col2": "received_date",
            "col3": "company", "col4": "city", "col5": "county", "col6": "employees_type"
        })

    return df

# %%
sample_std = standardize_warn_fragment(sample_df)
sample_std.head(10)
# Out:
#   notice_date effective_date received_date                 company  \
# 0  Unnamed: 0     Unnamed: 1    Unnamed: 2              Unnamed: 3
# 1         nan            nan           nan                     nan
# 2         nan            nan           nan                     nan
# 3      Notice      Effective      Received                     nan
# 4        Date           Date          Date                 Company
# 5  06/09/2020     06/07/2020    07/01/2020   Bay Club Santa Monica
# 6  06/19/2020     08/21/2020    07/01/2020       Weber Metals, Inc
# 7  06/09/2020     06/07/2020    07/01/2020  Bay Club Rolling Hills
# 8  06/09/2020     06/07/2020    07/01/2020  Bay Club Redondo Beach
# 9  06/09/2020     06/07/2020    07/01/2020    Bay Club Ross Valley
#
#                            city              county  \
# 0                   WARN Report          Unnamed: 4
# 1  Summary by State Fiscal Year                 nan
# 2  July 1, 2020 - June 30, 2021                 nan
# 3                           nan                 nan
# 4                          City              County
# 5                  Santa Monica  Los Angeles County
# 6                     Paramount  Los Angeles County
# 7         Rolling Hills Estates  Los Angeles County
# 8                 Redondo Beach  Los Angeles County
# 9                     Kentfield        Marin County
#
#                   employees_type                           col7  \
# 0                     Unnamed: 5  warn7-1-20to6-3-21_table0.csv
# 1                            nan  warn7-1-20to6-3-21_table0.csv
# 2                            nan  warn7-1-20to6-3-21_table0.csv
# 3                         No. Of  warn7-1-20to6-3-21_table0.csv
# 4  Employees Layoff/Closure Type  warn7-1-20to6-3-21_table0.csv
# 5            82 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 6           169 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 7            64 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 8           102 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
# 9            51 Layoff Permanent  warn7-1-20to6-3-21_table0.csv
#
#                      source_file address
# 0  warn7-1-20to6-3-21_table0.csv    <NA>
# 1  warn7-1-20to6-3-21_table0.csv    <NA>
# 2  warn7-1-20to6-3-21_table0.csv    <NA>
# 3  warn7-1-20to6-3-21_table0.csv    <NA>
# 4  warn7-1-20to6-3-21_table0.csv    <NA>
# 5  warn7-1-20to6-3-21_table0.csv    <NA>
# 6  warn7-1-20to6-3-21_table0.csv    <NA>
# 7  warn7-1-20to6-3-21_table0.csv    <NA>
# 8  warn7-1-20to6-3-21_table0.csv    <NA>
# 9  warn7-1-20to6-3-21_table0.csv    <NA>

# %% [markdown]
# 05: Split employees and layoff type
#
# In the extracted WARN tables, the last useful field often looks like:
# - 82 Layoff Permanent
# - 97 Closure Permanent
# - 71 Layoff Type Unknown
#
# We split this into:
# - employees
# - layoff_closure_type

# %%
def clean_warn_fragment(df: pd.DataFrame) -> pd.DataFrame:
    df = standardize_warn_fragment(df)

    # Convert to string first and strip spaces
    df["notice_date"] = df["notice_date"].astype(str).str.strip()

    # Keep only rows that look like mm/dd/yyyy before parsing
    mask = df["notice_date"].str.match(r"^\d{1,2}/\d{1,2}/\d{4}$", na=False)
    df = df[mask].copy()

    # Parse dates
    df["notice_date_dt"] = pd.to_datetime(
        df["notice_date"],
        format="%m/%d/%Y",
        errors="coerce"
    )

    df = df.dropna(subset=["notice_date_dt"]).copy()

    return df

# %%
sample_clean = clean_warn_fragment(sample_df)
sample_clean.head(10)
# Out:
#    notice_date effective_date received_date                   company  \
# 5   06/09/2020     06/07/2020    07/01/2020     Bay Club Santa Monica
# 6   06/19/2020     08/21/2020    07/01/2020         Weber Metals, Inc
# 7   06/09/2020     06/07/2020    07/01/2020    Bay Club Rolling Hills
# 8   06/09/2020     06/07/2020    07/01/2020    Bay Club Redondo Beach
# 9   06/09/2020     06/07/2020    07/01/2020      Bay Club Ross Valley
# 10  06/09/2020     06/07/2020    07/01/2020       StoneTree Golf Club
# 11  06/23/2020     06/23/2020    07/01/2020   The Freeman Company LLC
# 12  06/18/2020     03/20/2020    07/01/2020  Hyatt Regency Sacramento
# 13  06/18/2020     06/17/2020    07/01/2020       Granite Summit, Inc
# 14  06/18/2020     06/17/2020    07/01/2020                 Pali Camp
#
#                      city                 county          employees_type  \
# 5            Santa Monica     Los Angeles County     82 Layoff Permanent
# 6               Paramount     Los Angeles County    169 Layoff Permanent
# 7   Rolling Hills Estates     Los Angeles County     64 Layoff Permanent
# 8           Redondo Beach     Los Angeles County    102 Layoff Permanent
# 9               Kentfield           Marin County     51 Layoff Permanent
# 10                 Novato           Marin County     32 Layoff Permanent
# 11                Anaheim          Orange County     29 Layoff Permanent
# 12             Sacramento      Sacramento County    203 Layoff Permanent
# 13        Running Springs  San Bernardino County  60 Layoff Type Unknown
# 14        Running Springs  San Bernardino County  71 Layoff Type Unknown
#
#                              col7                    source_file address  \
# 5   warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 6   warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 7   warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 8   warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 9   warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 10  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 11  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 12  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 13  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
# 14  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv    <NA>
#
#    notice_date_dt
# 5      2020-06-09
# 6      2020-06-19
# 7      2020-06-09
# 8      2020-06-09
# 9      2020-06-09
# 10     2020-06-09
# 11     2020-06-23
# 12     2020-06-18
# 13     2020-06-18
# 14     2020-06-18

# %% [markdown]
# 06: Process all extracted fragments
#
# Now we apply the same cleaning pipeline to every extracted CSV fragment and combine them into one row-level WARN dataset.

# %%
cleaned_tables = []

for f in table_files:
    try:
        raw_df = load_warn_fragment(f)
        clean_df = clean_warn_fragment(raw_df)
        cleaned_tables.append(clean_df)
    except Exception as e:
        print(f"Skipped {os.path.basename(f)} because of error: {e}")

len(cleaned_tables)
# Out:
# 313

# %% [markdown]
# 07: Combine all cleaned WARN fragments
#
# At this point, each extracted CSV fragment has been:
# - loaded safely with `header=None`
# - standardized into a consistent column layout
# - filtered to keep valid notice dates
# - split into `employees` and `layoff_closure_type`
#
# Now we combine all cleaned fragments into one row-level WARN dataset.

# %%
# Combine all cleaned tables into one dataframe
warn_clean_rows = pd.concat(cleaned_tables, ignore_index=True)

print("Combined shape:", warn_clean_rows.shape)
warn_clean_rows.head(10)
# Out:
# Combined shape: (7426, 12)
#   notice_date effective_date received_date                   company  \
# 0  06/09/2020     06/07/2020    07/01/2020     Bay Club Santa Monica
# 1  06/19/2020     08/21/2020    07/01/2020         Weber Metals, Inc
# 2  06/09/2020     06/07/2020    07/01/2020    Bay Club Rolling Hills
# 3  06/09/2020     06/07/2020    07/01/2020    Bay Club Redondo Beach
# 4  06/09/2020     06/07/2020    07/01/2020      Bay Club Ross Valley
# 5  06/09/2020     06/07/2020    07/01/2020       StoneTree Golf Club
# 6  06/23/2020     06/23/2020    07/01/2020   The Freeman Company LLC
# 7  06/18/2020     03/20/2020    07/01/2020  Hyatt Regency Sacramento
# 8  06/18/2020     06/17/2020    07/01/2020       Granite Summit, Inc
# 9  06/18/2020     06/17/2020    07/01/2020                 Pali Camp
#
#                     city                 county          employees_type  \
# 0           Santa Monica     Los Angeles County     82 Layoff Permanent
# 1              Paramount     Los Angeles County    169 Layoff Permanent
# 2  Rolling Hills Estates     Los Angeles County     64 Layoff Permanent
# 3          Redondo Beach     Los Angeles County    102 Layoff Permanent
# 4              Kentfield           Marin County     51 Layoff Permanent
# 5                 Novato           Marin County     32 Layoff Permanent
# 6                Anaheim          Orange County     29 Layoff Permanent
# 7             Sacramento      Sacramento County    203 Layoff Permanent
# 8        Running Springs  San Bernardino County  60 Layoff Type Unknown
# 9        Running Springs  San Bernardino County  71 Layoff Type Unknown
#
#                             col7                    source_file address  \
# 0  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 1  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 2  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 3  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 4  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 5  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 6  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 7  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 8  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
# 9  warn7-1-20to6-3-21_table0.csv  warn7-1-20to6-3-21_table0.csv     NaN
#
#   notice_date_dt layoff_closure_type_raw
# 0     2020-06-09                     NaN
# 1     2020-06-19                     NaN
# 2     2020-06-09                     NaN
# 3     2020-06-09                     NaN
# 4     2020-06-09                     NaN
# 5     2020-06-09                     NaN
# 6     2020-06-23                     NaN
# 7     2020-06-18                     NaN
# 8     2020-06-18                     NaN
# 9     2020-06-18                     NaN

# %% [markdown]
# ## 08: Deduplicate repeated WARN rows
#
# PDF extraction can duplicate rows across fragments or pages.
# We remove duplicates using the main identifying columns.

# %%
before = len(warn_clean_rows)

warn_clean_rows = warn_clean_rows.drop_duplicates(
    subset=[
        "notice_date",
        "effective_date",
        "received_date",
        "company",
        "city",
        "county",
        "employees_type",
        "layoff_closure_type_raw",
        "address"
    ],
    keep="first"
)

after = len(warn_clean_rows)
print("Rows before dedup:", before)
print("Rows after dedup:", after)
print("Duplicates removed:", before - after)
# Out:
# Rows before dedup: 7426
# Rows after dedup: 7413
# Duplicates removed: 13

# %%
warn_final = warn_clean_rows.copy()

# %%
# Build one trusted event text field from possible columns
candidate_cols = [
    "employees_type",
    "layoff_closure_type",
    "layoff_closure_type_raw",
    "col7"
]

for col in candidate_cols:
    if col not in warn_final.columns:
        warn_final[col] = pd.NA

def first_valid_event_text(row):
    for col in candidate_cols:
        val = row[col]
        if pd.notna(val):
            txt = " ".join(str(val).split())
            if re.search(r"(?<!\d)\d{1,4}\s+(Layoff|Closure)\b", txt, flags=re.I):
                return txt
    return pd.NA

warn_final["event_text_raw"] = warn_final.apply(first_valid_event_text, axis=1)

# %%
# Keep only rows with real WARN event strings
warn_final = warn_final[warn_final["event_text_raw"].notna()].copy()

# %%
# Extract employee count safely from the validated event string
warn_final["employees"] = (
    warn_final["event_text_raw"]
    .str.extract(r"(?<!\d)(\d{1,4})\s+(Layoff|Closure)\b", expand=True)[0]
)

warn_final["employees"] = pd.to_numeric(warn_final["employees"], errors="coerce")

# %%
# Extract event label too
warn_final["layoff_closure_type"] = (
    warn_final["event_text_raw"]
    .str.extract(r"(?<!\d)\d{1,4}\s+(.+)$", expand=True)[0]
    .str.strip()
)

# %%
# Parse dates
warn_final["notice_date_dt"] = pd.to_datetime(warn_final["notice_date"], errors="coerce")

# Keep exact project window
warn_final = warn_final[
    (warn_final["notice_date_dt"] >= "2020-07-01") &
    (warn_final["notice_date_dt"] <= "2025-06-30")
].copy()

warn_final["month"] = warn_final["notice_date_dt"].dt.to_period("M").dt.to_timestamp()

# %%
# Manual validation: check suspiciously large rows
check_cols = [
    "notice_date", "company", "county", "address",
    "event_text_raw", "employees", "layoff_closure_type", "source_file"
]

display(
    warn_final[check_cols]
    .sort_values("employees", ascending=False)
    .head(30)
)
# Out:
#      notice_date                                            company  \
# 3517  03/31/2023                                            Walmart
# 1223  07/08/2020  United Airlines, Inc. - San Francisco Internat...
# 3973  09/21/2022                     Dreyer's Grand Ice Cream, Inc.
# 889   09/01/2020                                      Alorica, Inc.
# 431   07/15/2020  American Airlines, Inc. - Los Angeles Internat...
# 4431  10/18/2023                                    Ojai Valley Inn
# 861   08/18/2020                              Richmark Capital Corp
# 6764  03/12/2025                                 Gate Gourmet, Inc.
# 1817  12/09/2020                                           SeaWorld
# 4471  10/11/2023  Alvarado Hospital, LLC dba Alvarado Hospital M...
# 921   09/01/2020                               Options for Learning
# 5208  03/05/2024                                          Nordstrom
# 4079  11/04/2022                                      Twitter, Inc.
# 2037  12/15/2020                              Cohn Restaurant Group
# 2776  09/22/2022                       Smithfield Distribution, LLC
# 6088  10/29/2024                                    Ojai Valley Inn
# 1217  07/08/2020  United Airlines, Inc. - Los Angeles Internatio...
# 1888  07/15/2020                          DynCorp International LLC
# 3078  07/18/2022                                Invitae Corporation
# 7405  09/26/2024               Dreyer&rsquo;s Grand Ice Cream, Inc.
# 5230  03/04/2024                                   Northrop Grumman
# 5078  08/01/2023                                 Yellow Corporation
# 551   08/03/2020                      Marathon Petroleum Company LP
# 4917  01/05/2024                                Tower Semiconductor
# 6448  01/08/2025                                 Kohl&rsquo;s, Inc.
# 3125  01/04/2023                          Madera Community Hospital
# 2190  11/29/2021                     Watsonville Community Hospital
# 79    01/29/2021                              United Airlines - LAX
# 2189  11/26/2021                     Watsonville Community Hospital
# 2390  01/21/2022                     Watsonville Community Hospital
#
#                      county                           address  \
# 3517  San Bernardino County  warn7-1-22to06-30-23_table31.csv
# 1223   San Francisco County                               NaN
# 3973            Kern County   warn7-1-22to06-30-23_table5.csv
# 889           Fresno County                               NaN
# 431      Los Angeles County                               NaN
# 4431         Ventura County  warn7-1-23-to6-30-24_table19.csv
# 861      Los Angeles County                               NaN
# 6764   San Francisco County   warn7-1-24to6-30-25_table36.csv
# 1817       San Diego County                               NaN
# 4471       San Diego County  warn7-1-23-to6-30-24_table20.csv
# 921      Los Angeles County                               NaN
# 5208  San Bernardino County  warn7-1-23-to6-30-24_table44.csv
# 4079   San Francisco County   warn7-1-22to06-30-23_table9.csv
# 2037       San Diego County                               NaN
# 2776     Los Angeles County  warn7-1-22to06-30-23_table10.csv
# 6088         Ventura County   warn7-1-24to6-30-25_table14.csv
# 1217     Los Angeles County                               NaN
# 1888  San Bernardino County                               NaN
# 3078   San Francisco County   warn7-1-22to06-30-23_table2.csv
# 7405            Kern County    warn7-1-24to6-30-25_table9.csv
# 5230     Los Angeles County  warn7-1-23-to6-30-24_table45.csv
# 5078  San Bernardino County   warn7-1-23-to6-30-24_table4.csv
# 551     Contra Costa County                               NaN
# 4917          Orange County  warn7-1-23-to6-30-24_table35.csv
# 6448  San Bernardino County   warn7-1-24to6-30-25_table25.csv
# 3125          Madera County  warn7-1-22to06-30-23_table20.csv
# 2190      Santa Cruz County   warn7-1-21to6-30-22_table13.csv
# 79       Los Angeles County                               NaN
# 2189      Santa Cruz County   warn7-1-21to6-30-22_table13.csv
# 2390      Santa Cruz County   warn7-1-21to6-30-22_table22.csv
#
#                event_text_raw  employees layoff_closure_type  \
# 3517     953 Layoff Permanent        953    Layoff Permanent
# 1223   6,912 Layoff Temporary        912    Layoff Temporary
# 3973     905 Layoff Temporary        905    Layoff Temporary
# 889     891 Closure Permanent        891   Closure Permanent
# 431    1,890 Layoff Temporary        890    Layoff Temporary
# 4431    870 Closure Temporary        870   Closure Temporary
# 861      864 Layoff Permanent        864    Layoff Permanent
# 6764     835 Layoff Permanent        835    Layoff Permanent
# 1817     827 Layoff Temporary        827    Layoff Temporary
# 4471     808 Layoff Permanent        808    Layoff Permanent
# 921      789 Layoff Permanent        789    Layoff Permanent
# 5208    784 Closure Permanent        784   Closure Permanent
# 4079     784 Layoff Permanent        784    Layoff Permanent
# 2037     758 Layoff Permanent        758    Layoff Permanent
# 2776  1,755 Closure Permanent        755   Closure Permanent
# 6088     753 Layoff Temporary        753    Layoff Temporary
# 1217   1,750 Layoff Temporary        750    Layoff Temporary
# 1888     738 Layoff Permanent        738    Layoff Permanent
# 3078     736 Layoff Permanent        736    Layoff Permanent
# 7405     733 Layoff Temporary        733    Layoff Temporary
# 5230     731 Layoff Permanent        731    Layoff Permanent
# 5078    709 Closure Permanent        709   Closure Permanent
# 551      702 Layoff Permanent        702    Layoff Permanent
# 4917     699 Layoff Temporary        699    Layoff Temporary
# 6448    690 Closure Permanent        690   Closure Permanent
# 3125     687 Layoff Permanent        687    Layoff Permanent
# 2190    677 Closure Permanent        677   Closure Permanent
# 79       662 Layoff Temporary        662    Layoff Temporary
# 2189    658 Closure Permanent        658   Closure Permanent
# 2390    658 Closure Permanent        658   Closure Permanent
#
#                            source_file
# 3517  warn7-1-22to06-30-23_table31.csv
# 1223    warn7-1-20to6-3-21_table56.csv
# 3973   warn7-1-22to06-30-23_table5.csv
# 889     warn7-1-20to6-3-21_table39.csv
# 431     warn7-1-20to6-3-21_table16.csv
# 4431  warn7-1-23-to6-30-24_table19.csv
# 861     warn7-1-20to6-3-21_table38.csv
# 6764   warn7-1-24to6-30-25_table36.csv
# 1817    warn7-1-20to6-3-21_table86.csv
# 4471  warn7-1-23-to6-30-24_table20.csv
# 921     warn7-1-20to6-3-21_table40.csv
# 5208  warn7-1-23-to6-30-24_table44.csv
# 4079   warn7-1-22to06-30-23_table9.csv
# 2037    warn7-1-20to6-3-21_table97.csv
# 2776  warn7-1-22to06-30-23_table10.csv
# 6088   warn7-1-24to6-30-25_table14.csv
# 1217    warn7-1-20to6-3-21_table55.csv
# 1888     warn7-1-20to6-3-21_table9.csv
# 3078   warn7-1-22to06-30-23_table2.csv
# 7405    warn7-1-24to6-30-25_table9.csv
# 5230  warn7-1-23-to6-30-24_table45.csv
# 5078   warn7-1-23-to6-30-24_table4.csv
# 551     warn7-1-20to6-3-21_table21.csv
# 4917  warn7-1-23-to6-30-24_table35.csv
# 6448   warn7-1-24to6-30-25_table25.csv
# 3125  warn7-1-22to06-30-23_table20.csv
# 2190   warn7-1-21to6-30-22_table13.csv
# 79     warn7-1-20to6-3-21_table101.csv
# 2189   warn7-1-21to6-30-22_table13.csv
# 2390   warn7-1-21to6-30-22_table22.csv

# %% [markdown]
# Section 09

# %%
warn_final = warn_clean_rows.copy()

candidate_cols = ["employees_type", "layoff_closure_type", "layoff_closure_type_raw", "col7"]

for col in candidate_cols:
    if col not in warn_final.columns:
        warn_final[col] = pd.NA

# %%
def get_valid_event_text(row):
    for col in candidate_cols:
        val = row[col]
        if pd.notna(val):
            txt = " ".join(str(val).split())
            if re.search(r"(?<!\d)\d{1,4}\s+(Layoff|Closure)\b", txt, flags=re.I):
                return txt
    return pd.NA

warn_final["event_text_raw"] = warn_final.apply(get_valid_event_text, axis=1)
warn_final = warn_final[warn_final["event_text_raw"].notna()].copy()

# %%
warn_final["employees"] = (
    warn_final["event_text_raw"]
    .str.extract(r"(?<!\d)(\d{1,4})\s+(Layoff|Closure)\b", expand=True)[0]
)

warn_final["employees"] = pd.to_numeric(warn_final["employees"], errors="coerce")

warn_final["layoff_closure_type"] = (
    warn_final["event_text_raw"]
    .str.extract(r"(?<!\d)\d{1,4}\s+(.+)$", expand=True)[0]
    .str.strip()
)

# %%
warn_final["notice_date_dt"] = pd.to_datetime(warn_final["notice_date"], errors="coerce")

warn_final = warn_final[
    (warn_final["notice_date_dt"] >= "2020-07-01") &
    (warn_final["notice_date_dt"] <= "2025-06-30")
].copy()

warn_final["month"] = warn_final["notice_date_dt"].dt.to_period("M").dt.to_timestamp()

# %%
display(
    warn_final[
        ["notice_date", "company", "county", "address", "event_text_raw", "employees", "layoff_closure_type"]
    ]
    .sort_values("employees", ascending=False)
    .head(30)
)
# Out:
#      notice_date                                            company  \
# 3517  03/31/2023                                            Walmart
# 1223  07/08/2020  United Airlines, Inc. - San Francisco Internat...
# 3973  09/21/2022                     Dreyer's Grand Ice Cream, Inc.
# 889   09/01/2020                                      Alorica, Inc.
# 431   07/15/2020  American Airlines, Inc. - Los Angeles Internat...
# 4431  10/18/2023                                    Ojai Valley Inn
# 861   08/18/2020                              Richmark Capital Corp
# 6764  03/12/2025                                 Gate Gourmet, Inc.
# 1817  12/09/2020                                           SeaWorld
# 4471  10/11/2023  Alvarado Hospital, LLC dba Alvarado Hospital M...
# 921   09/01/2020                               Options for Learning
# 5208  03/05/2024                                          Nordstrom
# 4079  11/04/2022                                      Twitter, Inc.
# 2037  12/15/2020                              Cohn Restaurant Group
# 2776  09/22/2022                       Smithfield Distribution, LLC
# 6088  10/29/2024                                    Ojai Valley Inn
# 1217  07/08/2020  United Airlines, Inc. - Los Angeles Internatio...
# 1888  07/15/2020                          DynCorp International LLC
# 3078  07/18/2022                                Invitae Corporation
# 7405  09/26/2024               Dreyer&rsquo;s Grand Ice Cream, Inc.
# 5230  03/04/2024                                   Northrop Grumman
# 5078  08/01/2023                                 Yellow Corporation
# 551   08/03/2020                      Marathon Petroleum Company LP
# 4917  01/05/2024                                Tower Semiconductor
# 6448  01/08/2025                                 Kohl&rsquo;s, Inc.
# 3125  01/04/2023                          Madera Community Hospital
# 2190  11/29/2021                     Watsonville Community Hospital
# 79    01/29/2021                              United Airlines - LAX
# 2189  11/26/2021                     Watsonville Community Hospital
# 2390  01/21/2022                     Watsonville Community Hospital
#
#                      county                           address  \
# 3517  San Bernardino County  warn7-1-22to06-30-23_table31.csv
# 1223   San Francisco County                               NaN
# 3973            Kern County   warn7-1-22to06-30-23_table5.csv
# 889           Fresno County                               NaN
# 431      Los Angeles County                               NaN
# 4431         Ventura County  warn7-1-23-to6-30-24_table19.csv
# 861      Los Angeles County                               NaN
# 6764   San Francisco County   warn7-1-24to6-30-25_table36.csv
# 1817       San Diego County                               NaN
# 4471       San Diego County  warn7-1-23-to6-30-24_table20.csv
# 921      Los Angeles County                               NaN
# 5208  San Bernardino County  warn7-1-23-to6-30-24_table44.csv
# 4079   San Francisco County   warn7-1-22to06-30-23_table9.csv
# 2037       San Diego County                               NaN
# 2776     Los Angeles County  warn7-1-22to06-30-23_table10.csv
# 6088         Ventura County   warn7-1-24to6-30-25_table14.csv
# 1217     Los Angeles County                               NaN
# 1888  San Bernardino County                               NaN
# 3078   San Francisco County   warn7-1-22to06-30-23_table2.csv
# 7405            Kern County    warn7-1-24to6-30-25_table9.csv
# 5230     Los Angeles County  warn7-1-23-to6-30-24_table45.csv
# 5078  San Bernardino County   warn7-1-23-to6-30-24_table4.csv
# 551     Contra Costa County                               NaN
# 4917          Orange County  warn7-1-23-to6-30-24_table35.csv
# 6448  San Bernardino County   warn7-1-24to6-30-25_table25.csv
# 3125          Madera County  warn7-1-22to06-30-23_table20.csv
# 2190      Santa Cruz County   warn7-1-21to6-30-22_table13.csv
# 79       Los Angeles County                               NaN
# 2189      Santa Cruz County   warn7-1-21to6-30-22_table13.csv
# 2390      Santa Cruz County   warn7-1-21to6-30-22_table22.csv
#
#                event_text_raw  employees layoff_closure_type
# 3517     953 Layoff Permanent        953    Layoff Permanent
# 1223   6,912 Layoff Temporary        912    Layoff Temporary
# 3973     905 Layoff Temporary        905    Layoff Temporary
# 889     891 Closure Permanent        891   Closure Permanent
# 431    1,890 Layoff Temporary        890    Layoff Temporary
# 4431    870 Closure Temporary        870   Closure Temporary
# 861      864 Layoff Permanent        864    Layoff Permanent
# 6764     835 Layoff Permanent        835    Layoff Permanent
# 1817     827 Layoff Temporary        827    Layoff Temporary
# 4471     808 Layoff Permanent        808    Layoff Permanent
# 921      789 Layoff Permanent        789    Layoff Permanent
# 5208    784 Closure Permanent        784   Closure Permanent
# 4079     784 Layoff Permanent        784    Layoff Permanent
# 2037     758 Layoff Permanent        758    Layoff Permanent
# 2776  1,755 Closure Permanent        755   Closure Permanent
# 6088     753 Layoff Temporary        753    Layoff Temporary
# 1217   1,750 Layoff Temporary        750    Layoff Temporary
# 1888     738 Layoff Permanent        738    Layoff Permanent
# 3078     736 Layoff Permanent        736    Layoff Permanent
# 7405     733 Layoff Temporary        733    Layoff Temporary
# 5230     731 Layoff Permanent        731    Layoff Permanent
# 5078    709 Closure Permanent        709   Closure Permanent
# 551      702 Layoff Permanent        702    Layoff Permanent
# 4917     699 Layoff Temporary        699    Layoff Temporary
# 6448    690 Closure Permanent        690   Closure Permanent
# 3125     687 Layoff Permanent        687    Layoff Permanent
# 2190    677 Closure Permanent        677   Closure Permanent
# 79       662 Layoff Temporary        662    Layoff Temporary
# 2189    658 Closure Permanent        658   Closure Permanent
# 2390    658 Closure Permanent        658   Closure Permanent

# %%
os.makedirs("../data/processed", exist_ok=True)

warn_final.drop(columns=["notice_date_dt"], errors="ignore").to_csv(
    "../data/processed/warn_clean_rows.csv",
    index=False
)

warn_monthly = (
    warn_final.groupby("month", as_index=False)["employees"]
    .sum()
    .rename(columns={"employees": "warn_layoffs"})
    .sort_values("month")
)

warn_monthly.to_csv("../data/processed/warn_monthly.csv", index=False)

print("Saved clean files.")
warn_monthly.head(), warn_monthly.tail()
# Out:
# Saved clean files.
# (       month  warn_layoffs
#  0 2020-07-01         32814
#  1 2020-08-01         15544
#  2 2020-09-01         14535
#  3 2020-10-01         10477
#  4 2020-11-01          9323,
#          month  warn_layoffs
#  55 2025-02-01          7060
#  56 2025-03-01          5635
#  57 2025-04-01          6571
#  58 2025-05-01          5964
#  59 2025-06-01          3839)
